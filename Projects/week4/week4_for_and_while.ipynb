# %%
runnning = 10

for i in range(runnning):
    print("Round is :", i)
# Out:
# Round is : 0
# Round is : 1
# Round is : 2
# Round is : 3
# Round is : 4
# Round is : 5
# Round is : 6
# Round is : 7
# Round is : 8
# Round is : 9

# %%
check = True

while(check):
    print("Check")
    check = False
# Out:
# Check

# %%
runnning_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
runnning_int = int(runnning_str)

for i in range(runnning_int):
    print("Round is : ", i + 1)
# Out:
# Round is :  2
# Round is :  3
# Round is :  4
# Round is :  5
# Round is :  6
# Round is :  7
# Round is :  8
# Round is :  9
# Round is :  10
# Round is :  11

# %%
state = input("สั่งให้เริ่มวิ่ง ด้วยคำสั่ง 1")
state_runnning = True
if(state == '1'):
    state_runnning = True
else:
    state_runnning = False
i = 1
while(state):
    print("Round is : ", i)
    i = i + 1
    interup = input("ต้องการหยุดหรือไม่ 1 หยุด หรือ 0 เพื่อไปต่อจนกว่าจะขาขาด")
    if(interup == '1'):
        state = True
    elif(interup == '0'):
        state = False
# Out:
# Round is :  1
# Round is :  2
# Round is :  3
# Round is :  4

# %%
Q = "Press Q = Exit"
M = "Press M = Main"
S = "Press S = Start in Program"
state = True
while(state):
    print(Q)
    print(M)
    print(S)

    inp = input("Menu Selected : ")
    if(inp == 'Q'):
        state = False
    elif(inp == 'M'):
        print("Home Menu")
    elif(inp == 'S'):
        try:
            #ให้ผู้ใช้กรอกจำนวนรอบที่ต้องการ
            rounds_str = input("กรุณาระบุจำนวนรอบ (สูงสุด 10 รอบ): ")
            rounds = int(rounds_str)
            
            #ตรวจสอบเงื่อนไข: ถ้ากรอกมาเกิน 10 ให้ปรับเหลือแค่ 10 รอบเท่านั้น
            if rounds > 10:
                print(f"คุณใส่มา {rounds} รอบ เกินลิมิต! ระบบจะปรับให้เหลือ 10 รอบนะครับ")
                rounds = 10
            
            print(f"เริ่มวิ่งอย่างสนุกสนานกันเลย {rounds} รอบ เห้ออ...")
            
            #เริ่มวิ่งตามจำนวน rounds ที่ผ่านการตรวจสอบแล้ว
            for i in range(1, rounds + 1):
                print(f"วิ่งรอบที่ : {i}")
            
            print("เย้!! วิ่งครบแล้ว กลับไปหน้าเมนูกันเลย...")
            
        except ValueError:
            print("ผิดพลาด! กรุณาใส่ตัวเลขเท่านั้น อย่าใส่ตัวอักษรนะครับไม่งั้นผมจะใส่หน้าคุณ")
    else:
        print("Home Menu")
# Out:
# Press Q = Exit
# Press M = Main
# Press S = Start in Program
# ผิดพลาด! กรุณาใส่ตัวเลขเท่านั้น อย่าใส่ตัวอักษรนะครับไม่งั้นผมจะใส่หน้าคุณ
# Press Q = Exit
# Press M = Main
# Press S = Start in Program
# คุณใส่มา 60 รอบ เกินลิมิต! ระบบจะปรับให้เหลือ 10 รอบนะครับ
# เริ่มวิ่งอย่างสนุกสนานกันเลย 10 รอบ เห้ออ...
# วิ่งรอบที่ : 1
# วิ่งรอบที่ : 2
# วิ่งรอบที่ : 3
# วิ่งรอบที่ : 4
# วิ่งรอบที่ : 5
# วิ่งรอบที่ : 6
# วิ่งรอบที่ : 7
# วิ่งรอบที่ : 8
# วิ่งรอบที่ : 9
# วิ่งรอบที่ : 10
# เย้!! วิ่งครบแล้ว กลับไปหน้าเมนูกันเลย...
# Press Q = Exit
# Press M = Main
# Press S = Start in Program
